# %%
import numpy as np 
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ### Features 설명
# ######  Attrition_Flag : 고객 활동을 나타냄 (이탈한 고객1, 그렇지 않은 경우 0) 타겟 변수
# - CLIENTNUM : 고객 고유 식별자
# - Customer_Age : 고객의 나이 (수치)
# - Gender : 고객의 성별 (범주)
# - Dependent_count: 부양하는 가족 수 (범주)
# - Education_Level : 최종 학력 (고등학교, 대학졸업자, 박사 ...) (범주)
# - Marital_Status : 기혼, 미혼, 결혼, 알수 없음 (범주)
# - Income_Category : 연간 소득 (범주)
# - Card_Category : 카드 유형 (블루, 실버, 골드, 플래티넘) (범주)
# - Months_on_book : 은행과 거래한 기간 (수치)
# - Total_Relationship_Count :고객이 보유한 총 제품 수 (수치)
# - Months_Inactive_12_mon :지난 12개월 동안 비활성화 상태인 개월 수 (범주 0~6)
# - Contacts_Count_12_mon : 지난 12개월 동안 활동한 개월 수 (범주)
# - Credit_Limit : 신용카드 신용 한도 (수치)
# - Total_Revolving_Bal : 신용카드의 잔액 (수치)
# - Avg_Open_To_Buy : 신용 한도(구매 가능) 지난 12개월간 평균 (수치)
# - Total_Amt_Chng_Q4_Q1 :거래 금액의 변동 (1분기 대비 4분기) (수치)
# - Total_Trans_Amt : 12개월간 총 거래 금액 (수치)
# - Total_Trans_Ct : 12개월간 총 거래 수 (수치)
# - Total_Ct_Chng_Q4_Q1 :  거래 건수 변화 (1분기 대비 4분기) (수치)
# - Avg_Utilization_Ratio : 평균 카드 사용률 (수치)

# %% [markdown]
# ### 데이터 불러오기

# %%
data = pd.read_csv('./BankChurners.csv')

# %%
data = data.drop("Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1",axis=1)
data = data.drop("Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2", axis = 1)

# %% [markdown]
# ### 데이터 크기

# %%
print("Data shape{}".format(data.shape))
# Out:
# Data shape(10127, 21)

# %% [markdown]
# ### 데이터 확인

# %%
print("Data head\n{}".format(data.head()))
# Out:
# Data head
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 데이터 summary

# %%
print("Data summary\n{}".format(data.describe()))
# Out:
# Data summary
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %% [markdown]
# ### 데이터 타입확인

# %%
print("Data Info\n{}".format(data.info()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  17  Total_Trans_Amt           10127 non-null  int64
#  18  Total_Trans_Ct            10127 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  20  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 1.6+ MB
# Data Info
# None

# %% [markdown]
# ### 결측치 확인

# %%
msno.matrix(data,figsize=(12,5))

# %% [markdown]
# ##### 각 컬럼의 결측치 수

# %%
data.isnull().sum() #checking for total null values
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# # 클래스 분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Attrition_Flag'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('이탈한 고객과 아닌 고객')
ax[0].set_ylabel('')
sns.countplot('Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('이탈한 고객과 아닌 고객')
plt.show()

# %% [markdown]
# - 클래스의 불균형이 심함
# - 이탈한 고객이 1번으로 16.1% 비율을 보이고 있음

# %% [markdown]
# ## 범주형 데이터 별 분포 확인
# - Gender : 고객의 성별 (범주)
# - Dependent_count: 부양하는 가족 수 (범주)
# - Education_Level : 최종 학력 (고등학교, 대학졸업자, 박사 ...) (범주)
# - Marital_Status : 기혼, 미혼, 결혼, 알수 없음 (범주)
# - Income_Category : 연간 소득 (범주)
# - Card_Category : 카드 유형 (블루, 실버, 골드, 플래티넘) (범주)

# %% [markdown]
# ### 성별 분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Gender'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('성별')
ax[0].set_ylabel('')
sns.countplot('Gender',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('Gender에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석
# - 성별의 분포는 비슷한 경향을 보임
# - 이탈자와 아닌 사람 모두 여성에게서 높게 나타남

# %% [markdown]
# ### 부양가족 수  분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Dependent_count'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('부양 가족 수')
ax[0].set_ylabel('')
sns.countplot('Dependent_count',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('부양 가족 수에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석
# - 부양 가족 수는 2-3명이 전체의 절반 이상(53.2%)을 차지
# - 부양 가족 수와 이탈자의 수에서는 큰 관계가 없어보임

# %% [markdown]
# ### 최종 학력 분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Education_Level'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('최종 학력')
ax[0].set_ylabel('')
sns.countplot('Education_Level',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('최종 학력에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석
# - 대학교를 졸업한 사람이 가장 많고, 다음이 고등학교를 졸업한 사람이 많음

# %% [markdown]
# ### 혼인 여부 분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Marital_Status'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('혼인 여부')
ax[0].set_ylabel('')
sns.countplot('Marital_Status',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('혼인 여부에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석
# - 이혼을 한 사람이 전체의 7.4%임 / 결혼을 했거나 싱글인 사람들이 대부분을 이룸
# - 결혼을 한 사람과 싱글인 사람을 비교해 보았을 때 싱글인 사람들의 이탈율이 높을 것으로 예상이 됨.

# %% [markdown]
# ### 연간 소득 분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Income_Category'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('연간 소득')
ax[0].set_ylabel('')
sns.countplot('Income_Category',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('연간 소득에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석
# - 연간 소득 분포를 보았을 때 저소득인 사람이 많고, 고소득인 사람은 적음

# %% [markdown]
# ### 카드 유형별 분포 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Card_Category'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('카드 유형별')
ax[0].set_ylabel('')
sns.countplot('Card_Category',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('카드 유형에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석
# - 카드 유형을 보았을 때 대부분 Blue(일반)카드이고, platinum을 쓰는 사람은 극 소수임.

# %% [markdown]
# #### 지난 12개월 동안 비활성화 상태인 개월 수에 따른 이탈

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Months_Inactive_12_mon'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('지난 12개월 동안 카드 비활성화 상태인 개월 수')
ax[0].set_ylabel('')
sns.countplot('Months_Inactive_12_mon',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('지난 12개월 동안 카드 비활성화 상태인 개월 수에 따른 카드 해지 고객')
plt.show()

# %% [markdown]
# ###### 해석

# %% [markdown]
# #### 지난 12개월 동안 활동한 개월 수

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Contacts_Count_12_mon'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('지난 12개월 동안 연락처 수')
ax[0].set_ylabel('')
sns.countplot('Contacts_Count_12_mon',hue='Attrition_Flag',data=data,ax=ax[1])
ax[1].set_title('지난 12개월 동안 연락처 수에 따른 이탈자와 아닌 사람')
plt.show()

# %% [markdown]
# ###### 해석

# %% [markdown]
# - 내가 생각했을 때의 문제점
#     1. 일단 이탈자와 이탈하지 않은 사람의 클래스비율 차이가 많이 커서 countplot이 아닌 y축이 비율로 볼수 있는 그래프를 그리는 것이 더 좋지 않을 까 생각이 듬 .
#         - 따라서 비슷한 형태의 그래프가 계속 나오는 느낌 ..?

# %%
data['Gender'].replace(['M','F'], [0, 1], inplace=True)
data['Education_Level'].replace(['Doctorate','Post-Graduate','Graduate','College','High School','Uneducated', 'Unknown'],[0,1,2,3,4,5,6], inplace=True)
data['Attrition_Flag'].replace(['Attrited Customer', 'Existing Customer'], [1,0], inplace=True)

# %% [markdown]
# # 고객 최종 학력에 따른 이탈율

# %%
pd.crosstab([data.Gender,data.Attrition_Flag],data.Education_Level ,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col0 {
#             background-color:  #afd766;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col1 {
#             background-color:  #a8d366;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col2 {
#             background-color:  #a2d066;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col3 {
#             background-color:  #a5d266;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col4 {
#             background-color:  #9ece66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col5 {
#             background-color:  #a8d366;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col6 {
#             background-color:  #a6d266;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col7 {
#             background-color:  #a4d266;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col0 {
#             background-color:  #9dce66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col1 {
#             background-color:  #a1d066;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col2 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col3 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col4 {
#             background-color:  #9dce66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col5 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col6 {
#             background-color:  #9bcd66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow2_col7 {
#             background-color:  #9acc66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col0 {
#             background-color:  #ebf566;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col2 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col3 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col4 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col5 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col6 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow3_col7 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow4_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2a" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Education_Level</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="index_name level1" >Attrition_Flag</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2alevel0_row0" class="row_heading level0 row0" rowspan=2>0</th>
#                         <th id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2alevel1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col0" class="data row0 col0" >163</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col1" class="data row0 col1" >205</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col2" class="data row0 col2" >1264</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col3" class="data row0 col3" >406</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col4" class="data row0 col4" >851</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col5" class="data row0 col5" >581</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col6" class="data row0 col6" >602</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow0_col7" class="data row0 col7" >4072</td>
#             </tr>
#             <tr>
#                                 <th id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2alevel1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col0" class="data row1 col0" >31</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col1" class="data row1 col1" >48</td>
#                         <td id="T_a649b7f0_5bbb_11eb_a2c2_c809a8caaa2arow1_col2" class="da

# %%
sns.factorplot('Education_Level','Attrition_Flag',data=data)
sns.factorplot('Education_Level','Attrition_Flag',hue='Gender',data=data)
plt.show()
# Out:
# C:\Users\rlawj\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\rlawj\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# - 전체적으로 보았을 때 박사 과정 졸업에서 가장 많은 이탈을 보였음
# - 남여를 나눠서 비교해 보았을 때
# - 여자는 압도적으로 박사 과정 졸업에서 이탈이 많았고 점점 줄어드는 추세를 보임
# - 남자는 학벌이 높을 때 좀더 많은 이탈을 보임
# - 따라서 성별에 따라 카드 이탈율이 서로 다른 분포를 보이고 있음

# %% [markdown]
# # 지난 12개월 동안 비활성화 상태인 개월 수에 따른 남여 이탈 비교

# %%
sns.factorplot('Months_Inactive_12_mon','Attrition_Flag',data=data)
sns.factorplot('Months_Inactive_12_mon','Attrition_Flag',hue='Gender',data=data)
plt.show()
# Out:
# C:\Users\rlawj\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\rlawj\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# - 해석
#     - 일단 비활성화 상태인 0에서는 높은 이유가 이탈고객과 비이탈고객 둘다 비율이 비슷하기 때문 => 무시 가능
#     - 4개월로 갈수록 이탈율이 늘어나는데 다시 줄어듬
#     - 이유는 4개월 이상으로 휴먼하는 고객이 상대적으로 적기 때문인듯 따라서 앞부분인 4개월로 갈수록 이탈율이 늘어나는 것에 초점을 맞추면 어떨까 생각이 듬

# %% [markdown]
# # 이혼, 결혼, 미혼에 따른 연간 소득이 이탈율에 영향을 주는지

# %%
pd.crosstab([data.Marital_Status,data.Attrition_Flag],data.Income_Category,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col0 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col1 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col2 {
#             background-color:  #eff766;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col3 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col4 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col5 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow0_col6 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col1 {
#             background-color:  #9fcf66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col2 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col3 {
#             background-color:  #98cc66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col4 {
#             background-color:  #9fcf66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col5 {
#             background-color:  #a2d066;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow2_col6 {
#             background-color:  #9dce66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col0 {
#             background-color:  #eff766;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col3 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col4 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col5 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow3_col6 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col0 {
#             background-color:  #b5da66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col1 {
#             background-color:  #acd666;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col2 {
#             background-color:  #aed666;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col3 {
#             background-color:  #b4da66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col4 {
#             background-color:  #add666;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col5 {
#             background-color:  #add666;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow4_col6 {
#             background-color:  #afd766;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col0 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col1 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col2 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col3 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col4 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col5 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow5_col6 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col0 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col1 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col3 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col4 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col5 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow6_col6 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow7_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow8_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow8_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow8_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a88bb390_5bbb_11eb_a350_c809a8caaa2arow8_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;

# %%
sns.factorplot('Income_Category','Attrition_Flag',hue='Marital_Status',data=data)
plt.show()
# Out:
# C:\Users\rlawj\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# - 결혼한 사람은 대체적으로 수입에 상관없이 이탈율이 높은 편은 아님
# - 이혼한 사람은 수익이 너무 적거나 너무 많을 때 이탈율이 보통인 사람들에 비해서 낮음
# - 싱글인 사람들은 수익이 높을 수록 카드의 이탈율이 높음

# %% [markdown]
# # 최종 학력에 따른 카드 카테고리별 이탈수 비교

# %%
pd.crosstab([data.Education_Level,data.Attrition_Flag],data.Card_Category,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow0_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow0_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow0_col2 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow0_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow0_col4 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow1_col2 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow2_col0 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow2_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow2_col2 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow2_col3 {
#             background-color:  #f5fa66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow2_col4 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow3_col2 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow3_col3 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow4_col0 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow4_col1 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow4_col2 {
#             background-color:  #bfdf66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow4_col3 {
#             background-color:  #b8dc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow4_col4 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow5_col0 {
#             background-color:  #f5fa66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow5_col1 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow5_col2 {
#             background-color:  #d9ec66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow5_col3 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow5_col4 {
#             background-color:  #f5fa66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow6_col0 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow6_col1 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow6_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow6_col3 {
#             background-color:  #eaf466;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow6_col4 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow7_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow7_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow7_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow7_col3 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow7_col4 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow8_col0 {
#             background-color:  #d6eb66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow8_col1 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow8_col2 {
#             background-color:  #f3f966;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow8_col3 {
#             background-color:  #daec66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow8_col4 {
#             background-color:  #d6eb66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow9_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow9_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow9_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow9_col3 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow9_col4 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow10_col0 {
#             background-color:  #e2f066;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow10_col1 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow10_col2 {
#             background-color:  #d9ec66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow10_col3 {
#             background-color:  #e0f066;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow10_col4 {
#             background-color:  #e2f066;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow11_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow11_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow11_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow11_col3 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_a99d528a_5bbb_11eb_8afc_c809a8caaa2arow11_col4 {
#             background-color:  #fcfe66;
#             color:  #0

# %%
sns.factorplot('Education_Level','Attrition_Flag',hue='Card_Category',data=data)
plt.show()
# Out:
# C:\Users\rlawj\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# - 플래티넘 카드를 쓰는 사람의 학벌은 다 높음
# - gold 카드를 쓰는데 학벌이 낮은 사람의 이탈율이 높음

# %% [markdown]
# # 수치형 변수 이상치 판별

# %%
sns.boxplot(y = data['Customer_Age'], x = data['Attrition_Flag'])

# %%
sns.boxplot(y = data['Months_on_book'], x = data['Attrition_Flag']) #Months_on_book : 은행과 거래한 기간 (수치)

# %%
sns.boxplot(y = data['Total_Relationship_Count'], x = data['Attrition_Flag']) #Total_Relationship_Count :고객이 보유한 총 제품 수 (수치)

# %%
sns.boxplot(y = data['Credit_Limit'], x = data['Attrition_Flag']) #Credit_Limit : 신용카드 신용 한도 (수치)

# %%
sns.boxplot(y = data['Total_Revolving_Bal'], x = data['Attrition_Flag']) #Total_Revolving_Bal : 신용카드의 총 회전 잔액 (수치)

# %%
sns.boxplot(y = data['Total_Amt_Chng_Q4_Q1'], x = data['Attrition_Flag']) #Total_Amt_Chng_Q4_Q1 :거래 금액의 변동 (1분기 대비 4분기) (수치)

# %%
sns.boxplot(y = data['Total_Trans_Amt'], x = data['Attrition_Flag']) #Total_Trans_Amt : 12개월간 총 거래 금액 (수치)

# %%
sns.boxplot(y = data['Total_Trans_Ct'], x = data['Attrition_Flag']) #Total_Trans_Ct : 12개월간 총 거래 수 (수치)

# %%
sns.boxplot(y = data['Total_Ct_Chng_Q4_Q1'], x = data['Attrition_Flag'])#Total_Ct_Chng_Q4_Q1 : 거래 건수 변화 (1분기 대비 4분기) (수치)

# %%
sns.boxplot(y = data['Avg_Utilization_Ratio'], x = data['Attrition_Flag']) #Avg_Utilization_Ratio : 평균 카드 사용률 (수치)

# %% [markdown]
# # 연령에 따른 고객 이탈 비교

# %%
print('Max',data['Customer_Age'].max())
print('Min',data['Customer_Age'].min())
print('Average',data['Customer_Age'].mean())
# Out:
# Max 73
# Min 26
# Average 46.32596030413745

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Attrition_Flag']==0].Customer_Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Attrition_Flag= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Attrition_Flag']==1].Customer_Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Attrition_Flag= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# - 왼쪽(이탈하지 않음) / 오른쪽(이탈함)
# - 이탈하지 않은 사람을 보았을 때 40대 초반과 50대 초반에서 이탈하지 않은 사람이 갑자기 줄어드는것이 보임 하지만 40에서 40 중간에 이탈을 가장 많이 하지 않음
# - 이탈한 사람들을 보았을 때 40대 후반을 기준으로 정규분포의 형태를 보임 즉, 40대 후반전에는 이탈 비율이 적다가 점점 많아지지만 40대 후반 이후로는 다시 줄어드는 경향을 보이는 것

# %% [markdown]
# # 부양가족 수와 나이에 따른 이탈율

# %%
print('Max:',data['Avg_Utilization_Ratio'].max())
print('Min',data['Avg_Utilization_Ratio'].min())
print('Average',data['Avg_Utilization_Ratio'].mean())
# Out:
# Max: 0.9990000000000001
# Min 0.0
# Average 0.2748935518909845

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Dependent_count","Customer_Age", hue="Attrition_Flag", data=data,split=True,ax=ax[0])
ax[0].set_title('부양가족수와 나이에 따른 이탈율')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Income_Category","Customer_Age", hue="Attrition_Flag", data=data,split=True,ax=ax[1])  # 바이올린 플롯
ax[1].set_title('나이와 수입에 대한 이탈율 ')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# - 해석
# - 부양하는 가족 수가 많아 질수록 40-50대의 이탈율이 늘어남

# %% [markdown]
# # 이탈한 사람과 아닌 사람의 신용 한도(구매 가능) 지난 12개월간 평균

# %%
print('Max:',data['Avg_Open_To_Buy'].max())
print('Min :',data['Avg_Open_To_Buy'].min())
print('Average:',data['Avg_Open_To_Buy'].mean())
# Out:
# Max: 34516.0
# Min : 3.0
# Average: 7469.139636614887

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Attrition_Flag']==0].Avg_Open_To_Buy.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Attrition_Flag= 0')
x1=list(range(2,34600,200))
ax[0].set_xticks(x1)
data[data['Attrition_Flag']==1].Avg_Open_To_Buy.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Attrition_Flag= 1')
x2=list(range(2,34600,200))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# # 거래 건수 변화 (1분기 대비 4분기)가 클수록 이탈하는 사람이 작아지는지

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.distplot(data[data['Attrition_Flag']==0].Total_Ct_Chng_Q4_Q1 ,ax=ax[0])
ax[0].set_title('Total_Ct_Chng_Q4_Q1 in Attrition_Flag 0')
sns.distplot(data[data['Attrition_Flag']!=2].Total_Ct_Chng_Q4_Q1 ,ax=ax[0])
sns.distplot(data[data['Attrition_Flag']==1].Total_Ct_Chng_Q4_Q1 ,ax=ax[1])
ax[1].set_title('Total_Ct_Chng_Q4_Q1 in Attrition_Flag 1')
sns.distplot(data[data['Attrition_Flag']!=2].Total_Ct_Chng_Q4_Q1 ,ax=ax[1])
plt.show()

# %% [markdown]
# - 1분기와 4분기 거래 건수 변화가 크다는 것은 시간이 갈 수록 더 많은 이용을 했다는 의미
# - 그래프를 보면 거래건수 변화가 작을 때 이탈율이 더 큰 것으로 보임
#     - 즉, 카드 사용이 점점 줄다가 이탈로 이어진 것으로 보임

# %% [markdown]
# # 은행과 거래한 기간이 길수록 이탈하는 사람이 적은지

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.distplot(data[data['Attrition_Flag']==0].Months_on_book,ax=ax[0])
#sns.distplot(data[data['Attrition_Flag']!=2].Months_on_book,ax=ax[0])
ax[0].set_title('Months_on_book in Attrition_Flag 0')
sns.distplot(data[data['Attrition_Flag']==1].Months_on_book,ax=ax[1])
#sns.distplot(data[data['Attrition_Flag']!=2].Months_on_book,ax=ax[1])
ax[1].set_title('Months_on_book in Attrition_Flag 1')
plt.show()

# %% [markdown]
# - 은행과 거래한 기간이 짧을 수록 이탈하는 사람이 많을 것으로 예상했지만 은행과의 거래 기간의 3년 정도되면 이탈율이 심하게 많음
# - 이탈한 사람을 보았을 때 기간이 길어 질 수록 이탈하는 사람이 많은 것으로 보임

# %% [markdown]
# # 신용카드 잔액과 이탈비교

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.kdeplot(data[data['Attrition_Flag'] == 1]['Total_Revolving_Bal'], ax=ax)
sns.kdeplot(data[data['Attrition_Flag'] == 0]['Total_Revolving_Bal'], ax=ax)

plt.legend(['Existing', 'Attrited'])

plt.show()
# Out:
# C:\Users\rlawj\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\rlawj\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 해석 :  신용카드의 잔액이 적을 수록 해지하는 고객이 많음

# %% [markdown]
# # 평균 카드 사용률이 높을 수록 이탈하는 사람이 적은지

# %%
data['Avg_Utilization_Ratio'] = (data['Avg_Utilization_Ratio']*1000).astype(np.int64)

# %%
print('Max:',data['Avg_Utilization_Ratio'].max())
print('Min :',data['Avg_Utilization_Ratio'].min())
print('Average:',data['Avg_Utilization_Ratio'].mean())
# Out:
# Max: 999
# Min : 0
# Average: 274.8146538955268

# %%
f,ax=plt.subplots(1,3,figsize=(20,10))
data[data['Attrition_Flag']==0].Avg_Utilization_Ratio.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Attrition_Flag= 이탈을 하지 않은 고객')
x1=list(range(0,1000,100))
ax[0].set_xticks(x1)
data[data['Attrition_Flag']==1].Avg_Utilization_Ratio.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Attrition_Flag= 이탈한 고객')
x2=list(range(0,1000,100))
ax[1].set_xticks(x2)
data[data['Attrition_Flag']!= 2].Avg_Utilization_Ratio.plot.hist(ax=ax[2],color='blue',bins=20,edgecolor='black')
ax[2].set_title('Attrition_Flag')
x3=list(range(0,1000,100))
ax[2].set_xticks(x2)
plt.show()

# %% [markdown]
# - 평균 카드 사용률이 높을 수록 이탈하는 사람이 적어짐

# %% [markdown]
# ### 수치형 변수별 상관분석

# %%
sns.heatmap(data[["Customer_Age",
                  "Months_on_book",
                  "Total_Relationship_Count",
                  "Credit_Limit" ,
                  "Total_Revolving_Bal", 
                  "Avg_Open_To_Buy",
                  "Total_Amt_Chng_Q4_Q1", 
                  "Total_Trans_Amt", 
                  "Total_Trans_Ct", 
                  "Total_Ct_Chng_Q4_Q1",
                  "Avg_Utilization_Ratio"]].corr(),
            annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# - 수치형 상관분석 해석
#     1. Avg_Open_To_Buy와 Credit_Limit의 상관관계가 1로 나왔다.
#         - (Credit_Limit : 신용카드 신용 한도 / Avg_Open_To_Buy : 신용 한도(구매 가능) 지난 12개월간 평균)
#     2. Customer_Age와 Months_on_book의 상관관계가 0.79로 높은 양의 상관관계를 보인다.
#         - (Customer_Age : 고객의 나이 / Months_on_book : 은행과 거래한 기간)
#     3. Total_Trans_Amt와 Total_Trans_Ct의 상관관계가 0.81로 높은 양의 상관관계를 보인다.
#         - (Total_Trans_Amt : 12개월간 총 거래 금액 / Total_Trans_Ct : 12개월간 총 거래 수)

# %% [markdown]
# # 독립성 검정
# - target변수와 범주형 변수간의 관계 파악
# - 귀무가설 => 두 변수는 독립이다.
# - 대립가설 => 두 변수는 독립이 아니다.

# %% [markdown]
# ### 카드 비활성화 상태인 개월수와 이탈은 관계가 있나?
# - Months_Inactive_12_mon / Attrition_Flag
# - 위의 두 변수는 서로 독립이 아님 => 상관이 있음
#     - 카드 비활성화 상태인 개월 수가 길어질수록 이탈이 늘어남

# %%
cross_data_month = pd.crosstab(data['Months_Inactive_12_mon'], data['Attrition_Flag']  ,margins=True)
cross_data_month
# Out:
# Attrition_Flag             0     1    All
# Months_Inactive_12_mon
# 0                         14    15     29
# 1                       2133   100   2233
# 2                       2777   505   3282
# 3                       3020   826   3846
# 4                        305   130    435
# 5                        146    32    178
# 6                        105    19    124
# All                     8500  1627  10127

# %%
cross_prop_data_month = pd.crosstab(data['Months_Inactive_12_mon'], data['Attrition_Flag'] , normalize=True ,margins=True)
cross_prop_data_month
# Out:
# Attrition_Flag                 0         1       All
# Months_Inactive_12_mon
# 0                       0.001382  0.001481  0.002864
# 1                       0.210625  0.009875  0.220500
# 2                       0.274217  0.049867  0.324084
# 3                       0.298213  0.081564  0.379777
# 4                       0.030118  0.012837  0.042954
# 5                       0.014417  0.003160  0.017577
# 6                       0.010368  0.001876  0.012244
# All                     0.839340  0.160660  1.000000

# %%
from scipy.stats import chisquare
import scipy.stats as stats

# %%
chi_res  = stats.chi2_contingency(observed = cross_data_month)
print('Chi2 Statistic: {}, p-value: {}'.format(chi_res[0], chi_res[1]))
# Out:
# Chi2 Statistic: 396.45619934093764, p-value: 7.072411811462776e-76

# %% [markdown]
# ### 지난 12개월 동안 활동한 개월 수와 이탈은 관계가 있나?
# - Contacts_Count_12_mon / Attrition_Flag
# - 위의 두 변수는 독립이 아님 => 서로 상관이 있음
#      - 12개월 동안 활동한 개월 수가 많을 수록 이탈이 적음

# %%
cross_data_con = pd.crosstab(data['Contacts_Count_12_mon'], data['Attrition_Flag']  ,margins=True)
cross_data_con
# Out:
# Attrition_Flag            0     1    All
# Contacts_Count_12_mon
# 0                       392     7    399
# 1                      1391   108   1499
# 2                      2824   403   3227
# 3                      2699   681   3380
# 4                      1077   315   1392
# 5                       117    59    176
# 6                         0    54     54
# All                    8500  1627  10127

# %%
cross_data_prop_con = pd.crosstab(data['Contacts_Count_12_mon'], data['Attrition_Flag'] ,normalize=True ,margins=True)
cross_data_prop_con
# Out:
# Attrition_Flag                0         1       All
# Contacts_Count_12_mon
# 0                      0.038708  0.000691  0.039400
# 1                      0.137356  0.010665  0.148020
# 2                      0.278858  0.039795  0.318653
# 3                      0.266515  0.067246  0.333761
# 4                      0.106349  0.031105  0.137454
# 5                      0.011553  0.005826  0.017379
# 6                      0.000000  0.005332  0.005332
# All                    0.839340  0.160660  1.000000

# %%
chi_res  = stats.chi2_contingency(observed = cross_data_con)
print('Chi2 Statistic: {}, p-value: {}'.format(chi_res[0], chi_res[1]))
# Out:
# Chi2 Statistic: 586.6384841537745, p-value: 3.704478327296105e-116

# %% [markdown]
# ## poiontbiserialr correlation
# - 수치형 변수와 범주형 변수간의 관계 파악

# %%
stats.pointbiserialr(data['Total_Revolving_Bal'],data['Attrition_Flag'])
# Out:
# PointbiserialrResult(correlation=-0.26305288312920255, pvalue=6.63014845530425e-160)

# %%
stats.pointbiserialr(data['Total_Ct_Chng_Q4_Q1'],data['Attrition_Flag'])
# Out:
# PointbiserialrResult(correlation=-0.29005400688088834, pvalue=1.6477247846751795e-195)

# %%
stats.pointbiserialr(data['Avg_Utilization_Ratio'],data['Attrition_Flag'])
# Out:
# PointbiserialrResult(correlation=-0.17837612547381237, pvalue=3.579626905486274e-73)

# %% [markdown]
# - 결과
# - Total_Revolving_Bal와 Attrition_Flag 변수는 서로 상관이 있음
#      - 카드 잔액이 많을 수록 이탈이 줄어듬
# - Total_Ct_Chng_Q4_Q1와 Attrition_Flag 변수는 서로 상관이 있음
#      - 거래 건수 변화가 클수록 이탈이 줄어듬
# - Avg_Utilization_Ratio와 Attrition_Flag 변수는 서로 상관이 있음
#      - 카드 사용률이 클수록 이탈이 줄어듬

# %% [markdown]
# # modeling

# %% [markdown]
# ### up sampling - 복원추출

# %%
good, bad = data['Attrition_Flag'].value_counts()

df_good = data[data['Attrition_Flag'] == 0]
df_bad = data[data['Attrition_Flag'] == 1]

# %%
df_bad_up = df_bad.sample(good, replace=True)

df_up_fit = pd.concat([df_good, df_bad_up], axis=0)

df_up_fit['Attrition_Flag'].value_counts()
# Out:
# 1    8500
# 0    8500
# Name: Attrition_Flag, dtype: int64

# %% [markdown]
# ### down sampling

# %%
df_good_under = df_good.sample(bad)

df_under_fit = pd.concat([df_good_under, df_bad], axis=0)

df_under_fit['Attrition_Flag'].value_counts()
# Out:
# 1    1627
# 0    1627
# Name: Attrition_Flag, dtype: int64

# %% [markdown]
# ### train, test set 나누기

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=1)

# %% [markdown]
# ### upsampling train, test set 나누기

# %%
X_up_train, X_up_test = train_test_split(df_up_fit, test_size=0.2, random_state=1)

# %% [markdown]
# ## KFold 교차검증
# ![image.png](attachment:image.png)
# - 장점
#      1. 모든 데이터 셋을 평가에 활용할 수 있다.
#             - 평가에 사용되는 데이터 편중을 막을 수 있다.
#             (특정 평가 데이터 셋에 overfit 되는 것을 방지할 수 있다.)
#             - 평가 결과에 따라 좀 더 일반화된 모델을 만들 수 있다.
#
#      2. 모든 데이터 셋을 훈련에 활용할 수 있다.
#             - 정확도를 향상시킬 수 있다.
#             - 데이터 부족으로 인한 underfitting을 방지할 수 있다.
# - 단점
#     - teration 횟수가 많기 때문에 모델 훈련/평가 시간이 오래 걸린다.

# %% [markdown]
# ### random forest

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier

features= list(X_train)

kf=KFold(n_splits=10, shuffle=True)

print(type(kf))
x_dummies = pd.get_dummies(X_train)
fold_idx=1
accrs=[]
for train_index, val_index in kf.split(x_dummies):
    train_data, val_data = x_dummies.iloc[train_index],x_dummies.iloc[val_index]
    print('[Fold {}] validation accuracy={}'.format(fold_idx,mean_accuracy))
    #pca=PCA(n_components=20)
    
    train_y=train_data["Attrition_Flag"]
    #train_x=train_data[features]
    train_x = train_data.drop('Attrition_Flag', axis = 1)
    
    val_y=val_data["Attrition_Flag"]
    #test_x=test_data[features]
    val_x = val_data.drop('Attrition_Flag', axis = 1)
    
    model=forest = RandomForestClassifier(n_estimators=100)
    model.fit(train_x,train_y)
    
    mean_accuracy = model.score(val_x,val_y)
    fold_idx+=1
    

    accrs.append(mean_accuracy)

print("average accuracy = {}".format(np.average(accrs)))
# Out:
# <class 'sklearn.model_selection._split.KFold'>
# [Fold 1] validation accuracy=0.9889705882352942
# [Fold 2] validation accuracy=0.9568434032059187
# [Fold 3] validation accuracy=0.9592592592592593
# [Fold 4] validation accuracy=0.9506172839506173
# [Fold 5] validation accuracy=0.9530864197530864
# [Fold 6] validation accuracy=0.9592592592592593
# [Fold 7] validation accuracy=0.9481481481481482
# [Fold 8] validation accuracy=0.9543209876543209
# [Fold 9] validation accuracy=0.9580246913580247
# [Fold 10] validation accuracy=0.9518518518518518
# average accuracy = 0.9555608835304685

# %% [markdown]
# ### 오차 행렬

# %%
from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(model, train_x,train_y )

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(train_y, y_train_pred)
# Out:
# array([[6044,   78],
#        [ 284,  885]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score
precision = precision_score(train_y, y_train_pred)
recall = recall_score(train_y, y_train_pred)
print('precision = {}, recall = {}'.format(precision,recall))
# Out:
# precision = 0.9190031152647975, recall = 0.7570573139435415

# %% [markdown]
# # test

# %%
test_dummies = pd.get_dummies(X_test)
test_data = test_dummies.iloc[:]
test_y = test_data["Attrition_Flag"]
test_x = test_data.drop('Attrition_Flag', axis = 1)

# %%
model.score(test_x, test_y)
# Out:
# 0.9580454096742349

# %% [markdown]
# ### upsampling + ramdomforest

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier

features= list(X_up_train)

kf=KFold(n_splits=10, shuffle=True)

print(type(kf))
x_dummies = pd.get_dummies(X_up_train)
fold_idx=1
accrs=[]
for train_index, val_index in kf.split(x_dummies):
    train_data, val_data = x_dummies.iloc[train_index],x_dummies.iloc[val_index]
    print('[Fold {}] validation accuracy={}'.format(fold_idx,mean_accuracy))
    #pca=PCA(n_components=20)
    
    train_y=train_data["Attrition_Flag"]
    #train_x=train_data[features]
    train_x = train_data.drop('Attrition_Flag', axis = 1)
    
    val_y=val_data["Attrition_Flag"]
    #test_x=test_data[features]
    val_x = val_data.drop('Attrition_Flag', axis = 1)
    
    
    
    
    model=forest = RandomForestClassifier(n_estimators=100)
    model.fit(train_x,train_y)
    mean_accuracy = model.score(val_x,val_y)
    fold_idx+=1
    

    accrs.append(mean_accuracy)

print("average accuracy = {}".format(np.average(accrs)))
# Out:
# <class 'sklearn.model_selection._split.KFold'>
# [Fold 1] validation accuracy=0.9830882352941176
# [Fold 2] validation accuracy=0.9919117647058824
# [Fold 3] validation accuracy=0.9919117647058824
# [Fold 4] validation accuracy=0.9875
# [Fold 5] validation accuracy=0.9852941176470589
# [Fold 6] validation accuracy=0.9830882352941176
# [Fold 7] validation accuracy=0.986764705882353
# [Fold 8] validation accuracy=0.986764705882353
# [Fold 9] validation accuracy=0.9875
# [Fold 10] validation accuracy=0.9852941176470589
# average accuracy = 0.9870588235294118

# %% [markdown]
# ### 정밀도와 재현율

# %%
from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(model, train_x,train_y )

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(train_y, y_train_pred)
# Out:
# array([[6004,  152],
#        [  37, 6047]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score
precision = precision_score(train_y, y_train_pred)
recall = recall_score(train_y, y_train_pred)
print('precision = {}, recall = {}'.format(precision,recall))
# Out:
# precision = 0.9754799161155026, recall = 0.9939184746877054

# %% [markdown]
# ### test

# %%
test_up_dummies = pd.get_dummies(X_up_test)
test_up_data = test_up_dummies.iloc[:]
test_up_y = test_up_data["Attrition_Flag"]
test_up_x = test_up_data.drop('Attrition_Flag', axis = 1)

# %%
model.score(test_up_x, test_up_y)
# Out:
# 0.986764705882353

# %% [markdown]
# ### down sampling + randomforest

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier

features= list(df_under_fit)

kf=KFold(n_splits=10, shuffle=True)

print(type(kf))
x_dummies = pd.get_dummies(df_under_fit)
fold_idx=1
accrs=[]
for train_index, test_index in kf.split(x_dummies):
    train_data, test_data = x_dummies.iloc[train_index],x_dummies.iloc[test_index]
    
    #pca=PCA(n_components=20)
    
    train_y=train_data["Attrition_Flag"]
    #train_x=train_data[features]
    train_x = train_data.drop('Attrition_Flag', axis = 1)
    
    test_y=test_data["Attrition_Flag"]
    #test_x=test_data[features]
    test_x = test_data.drop('Attrition_Flag', axis = 1)
    
    model=forest = RandomForestClassifier(n_estimators=100)
    model.fit(train_x,train_y)
    
    mean_accuracy = model.score(test_x, test_y)
    fold_idx+=1
    accrs.append(mean_accuracy)

print("average accuracy = {}".format(np.average(accrs)))
# Out:
# <class 'sklearn.model_selection._split.KFold'>
# average accuracy = 0.9296153846153846

# %% [markdown]
# ### PCA + random forest

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier

features= list(X_up_train)

kf=KFold(n_splits=10, shuffle=True)

print(type(kf))
x_dummies = pd.get_dummies(X_up_train)
fold_idx=1
accrs=[]
for train_index, val_index in kf.split(x_dummies):
    train_data, val_data = x_dummies.iloc[train_index],x_dummies.iloc[val_index]
    print('[Fold {}] validation accuracy={}'.format(fold_idx,mean_accuracy))
    pca=PCA(n_components=10)
    
    train_y=train_data["Attrition_Flag"]
    #train_x=train_data[features]
    train_x = train_data.drop('Attrition_Flag', axis = 1)
    
    val_y=val_data["Attrition_Flag"]
    #test_x=test_data[features]
    val_x = val_data.drop('Attrition_Flag', axis = 1)
    
    
    
    
    model=forest = RandomForestClassifier(n_estimators=100)
    acc = model.fit(train_x,train_y)
    print(acc)
    mean_accuracy = model.score(val_x,val_y)
    fold_idx+=1
    

    accrs.append(mean_accuracy)

print("average accuracy = {}".format(np.average(accrs)))
# Out:
# <class 'sklearn.model_selection._split.KFold'>
# [Fold 1] validation accuracy=0.9882352941176471
# RandomForestClassifier()
# [Fold 2] validation accuracy=0.9882352941176471
# RandomForestClassifier()
# [Fold 3] validation accuracy=0.9882352941176471
# RandomForestClassifier()
# [Fold 4] validation accuracy=0.986764705882353
# RandomForestClassifier()
# [Fold 5] validation accuracy=0.9823529411764705
# RandomForestClassifier()
# [Fold 6] validation accuracy=0.986764705882353
# RandomForestClassifier()
# [Fold 7] validation accuracy=0.986764705882353
# RandomForestClassifier()
# [Fold 8] validation accuracy=0.9933823529411765
# RandomForestClassifier()
# [Fold 9] validation accuracy=0.9838235294117647
# RandomForestClassifier()
# [Fold 10] validation accuracy=0.9882352941176471
# RandomForestClassifier()
# average accuracy = 0.9873529411764705

# %% [markdown]
# # Auto ML

# %%
from pycaret.classification import *

# %%
clf = setup(data = X_train, target = 'Attrition_Flag')
# Out:
# <style  type="text/css" >
# </style><table id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow0_col1" class="data row0 col1" >3883</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow1_col1" class="data row1 col1" >Attrition_Flag</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow4_col1" class="data row4 col1" >(8101, 21)</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow6_col1" class="data row6 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow7_col1" class="data row7 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow11_col1" class="data row11 col1" >(5670, 58)</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow12_col1" class="data row12 col1" >(2431, 58)</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2alevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_8e136480_5bbd_11eb_a0cb_c809a8caaa2arow18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
best_3 = compare_models(sort = 'Recall', n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2a th {
#           text-align: left;
#     }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_d7f83c14_5bbd_11eb_9ac6_c809a8caaa2arow5_col8 {
#             text-align:  left;

# %% [markdown]
# ### 3개 모형 앙상블

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
#     #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col0 {
#             background:  yellow;
#         }    #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col1 {
#             background:  yellow;
#         }    #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col2 {
#             background:  yellow;
#         }    #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col3 {
#             background:  yellow;
#         }    #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col4 {
#             background:  yellow;
#         }    #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col5 {
#             background:  yellow;
#         }    #T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col6 {
#             background:  yellow;
#         }</style><table id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col0" class="data row0 col0" >0.9683</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col1" class="data row0 col1" >0.9883</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col2" class="data row0 col2" >0.9267</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col3" class="data row0 col3" >0.9678</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col4" class="data row0 col4" >0.9678</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col5" class="data row0 col5" >0.8772</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow0_col6" class="data row0 col6" >0.8780</td>
#             </tr>
#             <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col0" class="data row1 col0" >0.9603</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col1" class="data row1 col1" >0.9892</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col2" class="data row1 col2" >0.8970</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col3" class="data row1 col3" >0.9597</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col4" class="data row1 col4" >0.9591</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col5" class="data row1 col5" >0.8418</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow1_col6" class="data row1 col6" >0.8450</td>
#             </tr>
#             <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col0" class="data row2 col0" >0.9727</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col1" class="data row2 col1" >0.9944</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col2" class="data row2 col2" >0.9316</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col3" class="data row2 col3" >0.9723</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col4" class="data row2 col4" >0.9722</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col5" class="data row2 col5" >0.8936</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow2_col6" class="data row2 col6" >0.8947</td>
#             </tr>
#             <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col0" class="data row3 col0" >0.9771</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col1" class="data row3 col1" >0.9951</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col2" class="data row3 col2" >0.9478</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col3" class="data row3 col3" >0.9768</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col4" class="data row3 col4" >0.9769</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col5" class="data row3 col5" >0.9122</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow3_col6" class="data row3 col6" >0.9125</td>
#             </tr>
#             <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col0" class="data row4 col0" >0.9718</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col1" class="data row4 col1" >0.9931</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col2" class="data row4 col2" >0.9382</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col3" class="data row4 col3" >0.9714</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col4" class="data row4 col4" >0.9715</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col5" class="data row4 col5" >0.8924</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow4_col6" class="data row4 col6" >0.8927</td>
#             </tr>
#             <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col0" class="data row5 col0" >0.9700</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col1" class="data row5 col1" >0.9920</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col2" class="data row5 col2" >0.9282</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col3" class="data row5 col3" >0.9696</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col4" class="data row5 col4" >0.9695</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col5" class="data row5 col5" >0.8834</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow5_col6" class="data row5 col6" >0.8846</td>
#             </tr>
#             <tr>
#                         <th id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2alevel0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow6_col0" class="data row6 col0" >0.0056</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow6_col1" class="data row6 col1" >0.0028</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow6_col2" class="data row6 col2" >0.0171</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow6_col3" class="data row6 col3" >0.0057</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow6_col4" class="data row6 col4" >0.0059</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809a8caaa2arow6_col5" class="data row6 col5" >0.0236</td>
#                         <td id="T_f1497326_5bbd_11eb_af6a_c809

# %% [markdown]
# ### 앙상블 모형을 통한 예측

# %%
pred_holdout = predict_model(blended)
# Out:
# <style  type="text/css" >
# </style><table id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col0" class="data row0 col0" >Voting Classifier</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col1" class="data row0 col1" >0.9700</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col2" class="data row0 col2" >0.9945</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col3" class="data row0 col3" >0.9328</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col4" class="data row0 col4" >0.9696</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col5" class="data row0 col5" >0.9696</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col6" class="data row0 col6" >0.8880</td>
#                         <td id="T_f17dccd0_5bbd_11eb_9359_c809a8caaa2arow0_col7" class="data row0 col7" >0.8886</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(blended)
